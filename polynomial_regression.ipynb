# %% [markdown]
# # Polynomial Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
sns.set()
# %matplotlib inline
import os
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression,SGDRegressor
from sklearn.preprocessing import PolynomialFeatures,StandardScaler
from sklearn.metrics import r2_score

# %%
x = 6 * np.random.rand(200,1)-3
y= 0.8 * x**2+0.9*x+2+np.random.randn(200,1)

# %%
x.shape
# Out:
# (200, 1)

# %%
y.shape
# Out:
# (200, 1)

# %%
x
# Out:
# array([[-1.80156673],
#        [ 2.02040384],
#        [-1.73661328],
#        [-2.40769777],
#        [-1.20658019],
#        [-1.18604726],
#        [ 2.77582555],
#        [-2.31074427],
#        [ 0.59948539],
#        [-1.00305479],
#        [-2.39154133],
#        [ 2.5255706 ],
#        [ 1.779063  ],
#        [-0.97144959],
#        [-0.8589506 ],
#        [ 1.86904198],
#        [-2.79966521],
#        [ 0.90965621],
#        [-1.8802984 ],
#        [-2.79096262],
#        [ 0.45662071],
#        [-2.05957602],
#        [-2.20026915],
#        [ 1.06934208],
#        [-0.00337533],
#        [-0.54515241],
#        [ 0.11993393],
#        [ 0.5975181 ],
#        [ 0.01625617],
#        [-1.50747189],
#        [ 1.95131834],
#        [-0.07712906],
#        [-2.34965195],
#        [ 2.59254207],
#        [ 1.69261882],
#        [-1.99731164],
#        [ 2.71144941],
#        [ 1.45890437],
#        [-0.2112638 ],
#        [-2.30624285],
#        [-2.44390146],
#        [ 2.31635003],
#        [ 1.72454759],
#        [-0.19201085],
#        [-1.40953464],
#        [ 1.57338726],
#        [ 2.50856759],
#        [-0.96399836],
#        [-0.7950303 ],
#        [-0.43679418],
#        [ 1.07981922],
#        [ 2.26520292],
#        [-2.55245489],
#        [-2.61340251],
#        [ 2.44479249],
#        [-1.10307898],
#        [ 2.25357773],
#        [-0.62248408],
#        [ 1.81838781],
#        [ 2.07778061],
#        [ 2.50616267],
#        [ 1.72847994],
#        [-2.38204585],
#        [ 0.48975245],
#        [-2.9459594 ],
#        [ 2.56059949],
#        [-1.63232712],
#        [ 2.75314832],
#        [ 0.40867602],
#        [-0.77926242],
#        [-1.74254668],
#        [ 1.43824681],
#        [-0.6115281 ],
#        [-0.72066421],
#        [-0.43618978],
#        [-2.70270474],
#        [-0.39918353],
#        [ 2.58537088],
#        [ 0.25141766],
#        [ 0.15660044],
#        [-0.76934264],
#        [ 1.35055791],
#        [-0.6142843 ],
#        [ 1.99995637],
#        [-1.60162004],
#        [ 1.33305676],
#        [ 0.83115686],
#        [ 0.30298555],
#        [ 1.71906889],
#        [ 1.38524114],
#        [-0.46310547],
#        [ 0.84017601],
#        [ 0.97743078],
#        [ 0.8638683 ],
#        [ 2.69030329],
#        [-1.77664617],
#        [-1.47213464],
#        [ 1.08438649],
#        [-1.46652658],
#        [ 2.80276845],
#        [-2.25572985],
#        [-1.15432389],
#        [ 1.11393036],
#        [ 2.0661955 ],
#        [ 1.4918801 ],
#        [-1.8639274 ],
#        [ 0.75879876],
#        [-1.91912714],
#        [ 0.17749657],
#        [ 1.85084088],
#        [-1.94772047],
#        [-0.78357935],
#        [-2.01966398],
#        [ 0.5584623 ],
#        [-2.31801491],
#        [-2.37934009],
#        [-0.27261367],
#        [ 2.99019176],
#        [-0.15506916],
#        [-1.30770155],
#        [ 2.74604695],
#        [ 1.78916251],
#        [ 2.50273996],
#        [ 2.51561852],
#        [ 1.39975077],
#        [-0.48521746],
#        [ 2.48362819],
#        [ 2.37467873],
#        [ 2.26013024],
#        [-1.25122232],
#        [-2.88517327],
#        [ 2.32854701],
#        [ 0.4260433 ],
#        [ 0.58305994],
#        [ 1.61300181],
#        [ 1.4964551 ],
#        [-0.70151672],
#        [-0.36796778],
#        [-1.4488795 ],
#        [ 2.31294146],
#        [-2.39237599],
#        [-2.64828143],
#        [-2.93252373],
#        [-1.4308333 ],
#        [ 1.33636542],
#        [-0.35883092],
#        [-0.77917396],
#        [ 0.15715387],
#        [ 0.40459043],
#        [ 2.61285904],
#        [-1.03548839],
#        [-0.13505331],
#        [-1.10665373],
#        [-1.34942822],
#        [-0.59198628],
#        [ 1.56600202],
#        [ 1.62105033],
#        [-0.59996093],
#        [-1.39707887],
#        [ 1.45178474],
#        [ 1.06699662],
#        [ 1.48242408],
#        [-2.0419144 ],
#        [-2.30614173],
#        [ 0.76055812],
#        [-1.92402288],
#        [-0.45858951],
#        [-1.16722517],
#        [-2.88342479],
#        [-1.02022068],
#        [ 0.96164561],
#        [ 1.89013977],
#        [ 1.10810271],
#        [-2.5731874 ],
#        [-1.59234977],
#        [-0.05792769],
#        [-1.8939559 ],
#        [ 2.20921255],
#        [-2.12789514],
#        [ 2.16683805],
#        [ 0.59756297],
#        [ 1.85251535],
#        [-0.71234638],
#        [ 0.81921996],
#        [-0.52058311],
#        [ 1.32071747],
#        [ 0.67375848],
#        [-0.76405293],
#        [ 2.38671029],
#        [ 0.43938001],
#        [ 0.17712402],
#        [-1.10567255],
#        [-2.04675082],
#        [-0.63477749],
#        [ 1.69226681],
#        [-2.52068537],
#        [-1.71308119],
#        [ 2.2772813 ],
#        [ 1.64567997],
#        [ 1.02429255]])

# %%
y
# Out:
# array([[ 3.36593068],
#        [ 6.86362619],
#        [ 3.37420395],
#        [ 2.92930625],
#        [ 2.98803761],
#        [ 2.91397381],
#        [10.4448643 ],
#        [ 2.30354821],
#        [ 2.00363362],
#        [-0.05782242],
#        [ 3.09529062],
#        [ 9.78201812],
#        [ 4.49981216],
#        [ 1.01046544],
#        [ 3.27779145],
#        [ 7.63078564],
#        [ 6.84559927],
#        [ 3.75975557],
#        [ 3.64829651],
#        [ 5.16457811],
#        [ 2.34265438],
#        [ 3.64293835],
#        [ 4.36356203],
#        [ 3.82173411],
#        [ 2.81205316],
#        [ 1.57647201],
#        [ 3.21986662],
#        [ 2.1291802 ],
#        [ 2.75949283],
#        [ 1.80348653],
#        [ 6.83540091],
#        [ 1.6680359 ],
#        [ 4.9805287 ],
#        [10.54709922],
#        [ 5.11573065],
#        [ 3.6047699 ],
#        [10.50431277],
#        [ 5.55178176],
#        [ 1.76469124],
#        [ 5.00051601],
#        [ 4.19659749],
#        [ 9.66375671],
#        [ 7.03313532],
#        [-0.27655198],
#        [ 2.16992547],
#        [ 3.77425453],
#        [11.30382932],
#        [ 2.60444856],
#        [ 0.39383516],
#        [ 1.07506714],
#        [ 5.37570081],
#        [ 9.52542342],
#        [ 4.87891968],
#        [ 5.50568343],
#        [ 8.2222885 ],
#        [ 0.9391013 ],
#        [ 8.61669205],
#        [ 1.44502851],
#        [ 6.14946105],
#        [ 7.43635889],
#        [ 9.06801002],
#        [ 5.71281308],
#        [ 5.37097277],
#        [ 3.01393412],
#        [ 5.70042979],
#        [ 9.36952285],
#        [ 2.57440053],
#        [11.60630898],
#        [ 1.95260476],
#        [ 1.07825329],
#        [ 1.69522115],
#        [ 4.63240937],
#        [ 2.72057372],
#        [ 0.10599157],
#        [ 1.90195844],
#        [ 4.42167385],
#        [ 0.94879014],
#        [ 9.7617676 ],
#        [ 3.36122234],
#        [ 3.33645914],
#        [ 0.71347547],
#        [ 3.217855  ],
#        [ 2.36200167],
#        [ 6.76680856],
#        [ 3.4977756 ],
#        [ 5.39978048],
#        [ 3.74131348],
#        [ 1.812969  ],
#        [ 6.72632445],
#        [ 4.96987767],
#        [ 2.03355119],
#        [ 3.69809806],
#        [ 4.35078025],
#        [ 4.39495253],
#        [11.72042776],
#        [ 2.32304802],
#        [ 2.63051543],
#        [ 3.63003972],
#        [ 1.71681139],
#        [10.33940768],
#        [ 2.92656552],
#        [-0.26573678],
#        [ 4.52688451],
#        [ 7.18564492],
#        [ 4.90536219],
#        [ 2.51068268],
#        [ 2.63595965],
#        [ 3.59791801],
#        [ 4.12016314],
#        [ 6.51501927],
#        [ 1.29814993],
#        [ 2.61634474],
#        [ 4.80651953],
#        [ 3.06187136],
#        [ 3.74917524],
#        [ 3.51589126],
#        [ 2.35142385],
#        [12.20356547],
#        [ 2.31086816],
#        [ 1.58389851],
#        [11.14785175],
#        [ 4.89314914],
#        [ 7.32838212],
#        [ 9.73644775],
#        [ 6.04642338],
#        [ 0.03472824],
#        [ 9.14451045],
#        [ 8.26048415],
#        [ 9.0837744 ],
#        [ 1.8404962 ],
#        [ 6.66880726],
#        [ 9.46778755],
#        [ 2.97464841],
#        [ 1.28502242],
#        [ 5.89678524],
#        [ 6.23331355],
#        [ 0.23815222],
#        [ 2.09648395],
#        [ 1.15774577],
#        [ 9.05557776],
#        [ 4.57266539],
#        [ 7.57945335],
#        [ 5.57900337],
#        [ 1.21278574],
#        [ 4.1831482 ],
#        [ 0.18554689],
#        [ 2.88031539],
#        [ 2.17555627],
#        [ 3.56532531],
#        [10.09490497],
#        [ 2.52953835],
#        [ 1.64942655],
#        [ 1.31810352],
#        [ 2.12015428],
#        [ 1.68695555],
#        [ 6.53859497],
#        [ 5.66733156],
#        [ 2.17178932],
#        [ 2.57268745],
#        [ 5.01302933],
#        [ 3.39595447],
#        [ 4.68275984],
#        [ 4.08946817],
#        [ 5.20186662],
#        [ 3.73738518],
#        [ 5.06670347],
#        [ 2.22480801],
#        [ 3.18114208],
#        [ 5.94426288],
#        [ 2.25805255],
#        [ 2.30197302],
#        [ 7.71138656],
#        [ 6.33388434],
#        [ 5.58848092],
#        [ 2.80573937],
#        [ 0.19735647],
#        [ 2.16766897],
#        [ 7.67918384],
#        [ 3.20605798],
#        [ 8.16387713],
#        [ 1.60239806],
#        [ 6.87652551],
#        [ 1.15978196],
#        [ 2.8789812 ],
#        [-0.26470705],
#        [ 3.62011262],
#        [ 2.21367993],
#        [ 0.99505302],
#        [10.30793872],
#        [ 2.93880762],
#        [ 2.97915523],
#        [ 2.34871051],
#        [ 2.97279504],
#        [ 2.30464345],
#        [ 7.27529725],
#        [ 6.02447005],
#        [ 3.74464282],
#        [ 7.19949645],
#        [ 6.54061712],
#        [ 3.18460575]])

# %%
plt.plot(x,y,'b')
plt.xlabel('x dataset')
plt.ylabel('y dataset')
# Out:
# Text(0, 0.5, 'y dataset')

# %%
#split data into train and test

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=101)

# %%
#linear Regression model
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.2052827515882527

# %%
plt.scatter(x_train,lr.predict(x_train),color = 'r')
plt.plot(x,y,color = 'b')
plt.xlabel('x dataset')
plt.ylabel('y dataet')
# Out:
# Text(0, 0.5, 'y dataet')

# %% [markdown]
# So,using linear regression we found that our model is not that accurate therefore now we will use polynomial regression.

# %%
poly = PolynomialFeatures()

# %%
x_train_trans = poly.fit_transform(x_train)
x_test_trans = poly.fit_transform(x_test)

# %%
lr.fit(x_train_trans,y_train)
# Out:
# LinearRegression()

# %%
y_pre = lr.predict(x_test_trans)

# %%
y_pre
# Out:
# array([[ 5.17877841],
#        [ 6.63846952],
#        [ 1.88672616],
#        [ 4.93256082],
#        [ 2.49611304],
#        [ 2.04131069],
#        [ 9.3307402 ],
#        [ 1.67520749],
#        [ 1.70290745],
#        [ 6.05018635],
#        [ 2.50265048],
#        [ 3.26492701],
#        [ 2.43077246],
#        [ 1.84344468],
#        [ 5.03639289],
#        [10.19758161],
#        [ 1.65284046],
#        [ 6.01887677],
#        [ 3.68944156],
#        [ 3.99213122],
#        [ 4.08596082],
#        [ 2.09008944],
#        [ 1.90399383],
#        [ 6.1557093 ],
#        [ 9.92307798],
#        [ 4.00664483],
#        [ 6.14060196],
#        [ 1.97983476],
#        [ 7.99879525],
#        [ 2.67890035],
#        [ 6.35230112],
#        [ 2.82746548],
#        [ 1.66787142],
#        [ 3.70752331],
#        [ 8.69950125],
#        [ 4.11403059],
#        [ 1.66273368],
#        [ 2.63609614],
#        [ 2.14928598],
#        [ 2.85615618]])

# %%
r2_score(y_test,y_pre)
# Out:
# 0.8476127883595904
